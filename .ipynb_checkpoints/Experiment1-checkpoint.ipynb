# %%
import pandas as pd
import numpy as np
import torch
import os
import sys
sys.path.append(os.path.abspath("../scripts"))
import scripts
# Out:
#   Cell In[9], line 5
#     import ///../scripts
#            ^
# SyntaxError: invalid syntax

# %%
dataset = TUDataset(root='/tmp/ENZYMES', name='ENZYMES')
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File ~/.conda/envs/pytorch_env/lib/python3.10/site-packages/aiohttp/connector.py:1091, in TCPConnector._wrap_create_connection(self, addr_infos, req, timeout, client_error, *args, **kwargs)
#    1088 async with ceil_timeout(
#    1089     timeout.sock_connect, ceil_threshold=timeout.ceil_threshold
#    1090 ):
# -> 1091     sock = await aiohappyeyeballs.start_connection(
#    1092         addr_infos=addr_infos,
#    1093         local_addr_infos=self._local_addr_infos,
#    1094         happy_eyeballs_delay=self._happy_eyeballs_delay,
#    1095         interleave=self._interleave,
#    1096         loop=self._loop,
#    1097     )
#    1098     return await self._loop.create_connection(*args, **kwargs, sock=sock)
#
# ...

# %%
datasets.head()
